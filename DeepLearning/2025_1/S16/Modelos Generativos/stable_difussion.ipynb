# %%
# Paso 1: Instalar dependencias
# !pip install diffusers transformers accelerate safetensors

# Paso 2: Cargar el modelo
from diffusers import StableDiffusionPipeline
import torch

# Autenticarse si no has iniciado sesión en Hugging Face
# from huggingface_hub import notebook_login
# notebook_login()

# Paso 3: Cargar el pipeline
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16)
pipe = pipe.to("cuda")  # Usa GPU
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 59.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# Paso 4: Generar una imagen
prompt = "a cyberpunk cityscape at night with neon lights"
image = pipe(prompt).images[0]

# Mostrar la imagen
image.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# # Estructura sugerida para crear un buen prompt

# %% [markdown]
# [Objeto principal] + [estilo o tema] + [atributos visuales] + [calidad deseada] + [artistas de referencia]

# %%
# Save the image to a file
image_path = "generated_image.png"
image.save(image_path)

# Display the image
from IPython.display import Image, display
display(Image(filename=image_path))

# %%
prompt = "A cute robot in a colorful kitchen, smiling and holding a cupcake, cartoon style, Pixar-like rendering, soft lighting, cheerful mood, 3D animation look"
image = pipe(prompt).images[0]

# Mostrar la imagen
image.show()
# Save the image to a file
image_path = "generated_image2.png"
image.save(image_path)

# Display the image
from IPython.display import Image, display
display(Image(filename=image_path))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "A group of anime-style students in a modern classroom, studying deep learning, with futuristic holographic screens displaying neural networks and graphs, one student pointing at a glowing diagram, diverse characters, cheerful atmosphere, bright lighting, vibrant colors, ultra detailed, anime art style"

image = pipe(prompt).images[0]

# Mostrar la imagen
image.show()
# Save the image to a file
image_path = "generated_image3.png"
image.save(image_path)

# Display the image
from IPython.display import Image, display
display(Image(filename=image_path))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "A vibrant Pop Art style illustration representing the culture of Cali, Colombia: people dancing salsa in the streets, colorful colonial buildings, palm trees, the Cristo Rey statue in the background, traditional food like empanadas and lulada, tropical atmosphere, bold colors, comic book style halftone patterns, high contrast, inspired by Roy Lichtenstein and Andy Warhol"

image = pipe(prompt).images[0]

# Mostrar la imagen
image.show()
# Save the image to a file
image_path = "generated_image4.png"
image.save(image_path)

# Display the image
from IPython.display import Image, display
display(Image(filename=image_path))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "Two computer engineering students working together on a laptop in a university setting, with code and circuit diagrams in the background, wearing casual clothes, discussing a software project, comic book art style, bold lines, halftone textures, dynamic poses, colorful but technical atmosphere, in the style of classic comic books"

image = pipe(prompt).images[0]

# Mostrar la imagen
image.show()
# Save the image to a file
image_path = "generated_image5.png"
image.save(image_path)

# Display the image
from IPython.display import Image, display
display(Image(filename=image_path))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "A portrait of a mystical elven queen with silver hair, glowing green eyes, wearing an ornate crown made of leaves and gemstones, detailed ethereal clothing, soft lighting, intricate background with forest elements, highly detailed, 4k, cinematic lighting, art by Artgerm and Greg Rutkowski"

image = pipe(prompt).images[0]

# Mostrar la imagen
image.show()
# Save the image to a file
image_path = "generated_image6.png"
image.save(image_path)

# Display the image
from IPython.display import Image, display
display(Image(filename=image_path))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
